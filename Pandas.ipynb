# %% [markdown]
# <a href="https://colab.research.google.com/github/saravkulkarni/Innovation-Lab/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Pandas is a python library that allows you to work with large data sets. You can clean the data and then analyse it.

# %% [markdown]
# In the following example, data has been taken from NASA open data portal. Clicking on this link will take you to the page where you can read and learn more about the study:
#  https://data.nasa.gov/dataset/pyrocumulonimbus-events-over-british-columbia-in-august-2017-results-from-the-nasa-geos-ea
#
#  The study involved modelling smoke aerosols to look at long term impacts in the stratosphere. You can read more about it by looking at the website. You can also find other data they collected there.
#
#  Use the comments in the code below to help you understand what is going on. It is also incredibly helpful to have the original data set, so you can make sense of the outputs. This can be found by clicking on the link above and downloading the first CSV file.

# %%
import pandas as pd
# This is where the CSV file has been stored.
url = "https://raw.githubusercontent.com/saravkulkarni/Innovation-Lab/refs/heads/main/Data/Plumetop_heights_timeseries.csv"
df = pd.read_csv(url)
# This gives you more information about the data you have. Read the next text section to learn more about the output of this.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Days from Injection                                               31 non-null     int64
#  1   OMPS-LP Plume top heights (km)                                    31 non-null     float64
#  2   Model plume top height (km, passive aerosols)                     31 non-null     float64
#  3   Model plume top height (km, point source emissions)               31 non-null     float64
#  4   Model plume top height (km, smeared emissions)                    31 non-null     float64
#  5   Model plume top height (km, smeared emissions + modified optics)  31 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 1.6 KB
# None

# %% [markdown]
# Firstly, it gives you the number of entries, followed by the number of columns. Alongside the name of each column, it provides you with the data type, such as integer or float as shown above. It also tells you whether you have any null values. This information may be important when it comes to cleaning your data.

# %%
import pandas as pd
# This is where the CSV file has been stored.
url = "https://raw.githubusercontent.com/saravkulkarni/Innovation-Lab/refs/heads/main/Data/Plumetop_heights_timeseries.csv"
df = pd.read_csv(url)
# This prints the first 3 rows. Note that if there is no number, the first 5 will be printed.
print(df.head(3))
# This prints the last 3 rows.
print(df.tail(3))
# Out:
#    Days from Injection   OMPS-LP Plume top heights (km)  \
# 0                     0                            12.5
# 1                     1                            14.5
# 2                     2                            14.5
#
#    Model plume top height (km, passive aerosols)  \
# 0                                           12.5
# 1                                           13.5
# 2                                           13.5
#
#    Model plume top height (km, point source emissions)  \
# 0                                               13.5
# 1                                               15.5
# 2                                               17.5
#
#    Model plume top height (km, smeared emissions)  \
# 0                                            12.5
# 1                                            14.5
# 2                                            15.5
#
#    Model plume top height (km, smeared emissions + modified optics)
# ...

# %% [markdown]
# The next step after this is cleaning your data, and this is highly crucial. This will be covered in chapter 3.

# %% [markdown]
# **Exercise**
#
#
# *   Find your own data or use the data from this example
# *   Find out the number or entries there are, the number of columns, and whether there are any null entries
# * Print a subsection of the data out
# * Figure out how to plot part of the data using matplotlib

# %% [markdown]
# The data used has a universal creative commons license. It is in the public domain. However the following reference is provided.     Pyrocumulonimbus events over British Columbia in August 2017: Results from the NASA GEOS earth system model - NASA open data portal (2025) NASA. Available at: https://data.nasa.gov/dataset/pyrocumulonimbus-events-over-british-columbia-in-august-2017-results-from-the-nasa-geos-ea (Accessed: 19 August 2026).
